# %%
# %matplotlib widget 
# %matplotlib qt
from xspec_interactive_plot import XSPECInteractivePlot

# %%
Dir = '../eROSITA_DR4/G213.0-00.6/Spectra/'
bkgfile="BKG_circ_820_SourceSpec_00001_corr.fits"

rmf = "BKG_circ_820_RMF_00001.fits"
arf = "BKG_circ_820_ARF_00001_corr.fits"

model_name = "apec+powerlaw"
param_defaults = [
    0.112416,
    1,
    1.1,
    1
]

label_list = [r"$\mathrm{apec_{Corona}}$", r"$\mathrm{powerlaw}$"]

# %%
plotter = XSPECInteractivePlot(Dir, bkgfile, rmf, arf, model_name, param_defaults, label_list, xspec_type='src')
plotter.run()
# Out:
# VBox(children=(HBox(children=(VBox(children=(FloatSlider(value=0.23796168324405942, description='apec.kT', max…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
